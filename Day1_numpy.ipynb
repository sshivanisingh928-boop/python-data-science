# %%
import numpy as np

# Generate random scores
scores = np.random.randint(0, 100, size=50)

print("Scores:")
print(scores)

# Statistics
print("\nMean:", np.mean(scores))
print("Median:", np.median(scores))
print("Highest:", np.max(scores))
print("Lowest:", np.min(scores))
print("Standard Deviation:", np.std(scores))

# Percentiles
print("25th Percentile:", np.percentile(scores, 25))
print("75th Percentile:", np.percentile(scores, 75))

# Failed and distinction students
print("\nFailed Students (<40):")
print(scores[scores < 40])

print("\nDistinction Students (>85):")
print(scores[scores > 85])

# Normalize scores
normalized_scores = (scores - np.min(scores)) / (np.max(scores) - np.min(scores))

print("\nNormalized Scores:")
print(normalized_scores)

# Reshape array
reshaped_scores = scores.reshape(5, 10)

print("\n5x10 Score Matrix:")
print(reshaped_scores)

# Row-wise averages
subject_avg = np.mean(reshaped_scores, axis=1)

print("\nSubject-wise Average Scores:")
print(subject_avg)

# Bonus challenge
theory = np.random.randint(0, 100, size=50)
practical = np.random.randint(0, 100, size=50)

final_scores = (0.4 * theory) + (0.6 * practical)

print("\nWeighted Final Scores:")
print(final_scores)
# Out:
# Scores:
# [ 8  4 61 49 87 95 46 35 47 96 21 15 17 39 28 35 73 79 83 31  4 23 89 32
#  24  0 25 28 37 10 32 91 25 33  6 77 40 20 22 96 69 77 61 72  2 61 81 86
#  37 56]
#
# Mean: 45.3
# Median: 37.0
# Highest: 96
# Lowest: 0
# Standard Deviation: 29.0766229125736
# 25th Percentile: 23.25
# 75th Percentile: 72.75
#
# Failed Students (<40):
# [ 8  4 35 21 15 17 39 28 35 31  4 23 32 24  0 25 28 37 10 32 25 33  6 20
#  22  2 37]
#
# Distinction Students (>85):
# [87 95 96 89 91 96 86]
#
# Normalized Scores:
# [0.08333333 0.04166667 0.63541667 0.51041667 0.90625    0.98958333
#  0.47916667 0.36458333 0.48958333 1.         0.21875    0.15625
#  0.17708333 0.40625    0.29166667 0.36458333 0.76041667 0.82291667
#  0.86458333 0.32291667 0.04166667 0.23958333 0.92708333 0.33333333
#  0.25       0.         0.26041667 0.29166667 0.38541667 0.10416667
#  0.33333333 0.94791667 0.26041667 0.34375    0.0625     0.80208333
#  0.41666667 0.20833333 0.22916667 1.         0.71875    0.80208333
#  0.63541667 0.75       0.02083333 0.63541667 0.84375    0.89583333
#  0.38541667 0.58333333]
#
# 5x10 Score Matrix:
# [[ 8  4 61 49 87 95 46 35 47 96]
#  [21 15 17 39 28 35 73 79 83 31]
#  [ 4 23 89 32 24  0 25 28 37 10]
#  [32 91 25 33  6 77 40 20 22 96]
#  [69 77 61 72  2 61 81 86 37 56]]
#
# Subject-wise Average Scores:
# [52.8 42.1 27.2 44.2 60.2]
#
# Weighted Final Scores:
# [34.6 72.8 91.6 75.2  3.  35.2 13.  37.6 46.4 52.  36.  55.8 43.4 34.
#  61.8 29.  43.2 48.  14.4 44.8 25.8 44.2 34.2 31.2 84.2 73.  63.2 72.8
#  35.8 60.  48.8 38.6 70.4 16.8 59.2 58.  47.8 42.2 52.2 45.4 73.8 22.6
#  37.8 40.  23.4 66.  69.2 58.8 32.  28.6]
