# %%
import numpy as np
s=[[1,2,3],[3,4,5],[5,6,7]]
s1=np.array(s)
print(s1[1])
print(s1[2])
print(s1[-1])
print(s1[1][1])
print(s1[1][-1])
print(s1[-1][-2])
print(s1[1][0])
s1[0][0]=12
s2=(s1+s1)
print(s2)
print([[s1],[s1]])
# Out:
# [3 4 5]
# [5 6 7]
# [5 6 7]
# 4
# 5
# 6
# 3
# [[24  4  6]
#  [ 6  8 10]
#  [10 12 14]]
# [[array([[12,  2,  3],
#        [ 3,  4,  5],
#        [ 5,  6,  7]])], [array([[12,  2,  3],
#        [ 3,  4,  5],
#        [ 5,  6,  7]])]]
